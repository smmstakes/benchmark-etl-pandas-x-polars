# %% [markdown]
# # Arquitetura de Recomendação: Spotify vs YouTube - Uma Análise Comparativa

# %% [markdown]
# ## Importando as bibliotecas necessárias

# %%
import matplotlib.pyplot as plt
import numpy as np
import polars as pl
import seaborn as sns
from dotenv import load_dotenv
